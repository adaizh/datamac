# %%
#install.packages('maps')
library(ggplot2)
library(dplyr)
library(maps)

# %%
NZ <- map_data("world") %>% filter(region=="NZ")
nz.data <- world.cities %>% filter(country.etc=="NZ")
map('nz',col="black", lwd=1, mar=rep(0,4) )
# Out:
# plot without title
